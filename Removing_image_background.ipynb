# %% [markdown]
# <a href="https://colab.research.google.com/github/HenryMorganDibie/Python/blob/main/Removing_image_background.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rembg
import rembg
from PIL import Image
import rembg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
Img = Image.open('drive/MyDrive/Removing image background/23e97afa88145f0b68dc79d45f7614dd.jpg')
Img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

# %%
Img_bg_removed = rembg.remove(Img)
Img_bg_removed
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tCU5MM1LhRgGou5OpmpjBQbSrYIUoYab
# To: /root/.u2net/u2net.onnx
# 100%|██████████| 176M/176M [00:00<00:00, 247MB/s]
# <PIL.Image.Image image mode=RGBA size=500x500>
